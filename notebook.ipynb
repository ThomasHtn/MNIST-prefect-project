# %%
# %run app/train.py
# Out:
# ✨ First training: using data augmentation
# 🛠 Building new model
# Epoch 1/20
# /home/thomas/atlas/projects/MNIST-prefect-project/.venv/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/thomas/atlas/projects/MNIST-prefect-project/.venv/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# ...

# %%
# %run app/evaluate.py
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ✅ Modèle chargé depuis models/latest_model.h5
# 🎯 Test Accuracy: 0.9947
# 📉 Test Loss: 0.0172
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# Classification Report :
#               precision    recall  f1-score   support
#
#            0     0.9980    0.9990    0.9985       980
#            1     0.9974    0.9956    0.9965      1135
#            2     0.9961    0.9961    0.9961      1032
#            3     0.9911    0.9970    0.9941      1010
#            4     0.9899    0.9959    0.9929       982
#            5     0.9977    0.9899    0.9938       892
#            6     0.9958    0.9937    0.9948       958
#            7     0.9951    0.9942    0.9946      1028
#            8     0.9898    0.9969    0.9934       974
#            9     0.9960    0.9881    0.9920      1009
#
# ...

# %%
# %run app/train-optuna.py
# Out:
# [I 2025-07-09 11:59:35,320] A new study created in memory with name: no-name-4df806d4-08e5-44ca-8a1b-fb0b3adf2f0d
# /home/thomas/atlas/projects/MNIST-prefect-project/.venv/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-07-09 11:59:35.335762: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-07-09 11:59:35.335783: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:167] env: CUDA_VISIBLE_DEVICES="-1"
# ...
